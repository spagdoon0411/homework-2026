# %%
import sympy as sp
from IPython.display import display, Math

# %%
# Set up symbolic matrix for inversion
# Define symbols for quadrupole moment matrix
Bi, Bii, Biii, n1, n2, I = sp.symbols("B_i B_ii B_iii n_1 n_2 I", real=True)
A = sp.Matrix([[1, -1, 0], [1, 0, -1], [0, 1, -1]])

# Compute the inverse of the matrix symbolically
A_inv = A.inv()

# Display the inverse matrix
print("Inverse of the quadrupole moment matrix:")
display(Math(sp.latex(A_inv)))
# Out:
# ---------------------------------------------------------------------------
# DMNonInvertibleMatrixError                Traceback (most recent call last)
# File ~/Projects/homework/phys305/.venv/lib/python3.13/site-packages/sympy/matrices/inverse.py:326, in _inv_DM(dM, cancel)
#     325 try:
# --> 326     dMi, den = dM.inv_den()
#     327 except DMNonInvertibleMatrixError:
#
# File ~/Projects/homework/phys305/.venv/lib/python3.13/site-packages/sympy/polys/matrices/domainmatrix.py:2743, in DomainMatrix.inv_den(self, method)
#    2742 I = self.eye(self.shape, self.domain)
# -> 2743 return self.solve_den(I, method=method)
#
# File ~/Projects/homework/phys305/.venv/lib/python3.13/site-packages/sympy/polys/matrices/domainmatrix.py:2883, in DomainMatrix.solve_den(self, b, method)
#    2882 elif method == 'rref':
# -> 2883     xnum, xden = self.solve_den_rref(b)
#    2884 else:
#
# File ~/Projects/homework/phys305/.venv/lib/python3.13/site-packages/sympy/polys/matrices/domainmatrix.py:2935, in DomainMatrix.solve_den_rref(self, b)
#    2934 if len(pivots) != n or pivots and pivots[-1] >= n:
# -> 2935     raise DMNonInvertibleMatrixError("Non-unique solution.")
#    2937 xnum = Aaug_rref[:n, n:]
#
# DMNonInvertibleMatrixError: Non-unique solution.
#
# During handling of the above exception, another exception occurred:
#
# NonInvertibleMatrixError                  Traceback (most recent call last)
# Cell In[6], line 7
#       4 A = sp.Matrix([[1, -1, 0], [1, 0, -1], [0, 1, -1]])
#       6 # Compute the inverse of the matrix symbolically
# ----> 7 A_inv = A.inv()
#       9 # Display the inverse matrix
#      10 print("Inverse of the quadrupole moment matrix:")
#
# File ~/Projects/homework/phys305/.venv/lib/python3.13/site-packages/sympy/matrices/matrixbase.py:5223, in MatrixBase.inv(self, method, iszerofunc, try_block_diag)
#    5222 def inv(self, method=None, iszerofunc=_iszero, try_block_diag=False):
# -> 5223     return _inv(self, method=method, iszerofunc=iszerofunc,
#    5224             try_block_diag=try_block_diag)
#
# File ~/Projects/homework/phys305/.venv/lib/python3.13/site-packages/sympy/matrices/inverse.py:504, in _inv(M, method, iszerofunc, try_block_diag)
#     501         method = 'GE'
#     503 if method == "DM":
# --> 504     rv = _inv_DM(dM)
#     505 elif method == "DMNC":
#     506     rv = _inv_DM(dM, cancel=False)
#
# File ~/Projects/homework/phys305/.venv/lib/python3.13/site-packages/sympy/matrices/inverse.py:328, in _inv_DM(dM, cancel)
#     326     dMi, den = dM.inv_den()
#     327 except DMNonInvertibleMatrixError:
# --> 328     raise NonInvertibleMatrixError("Matrix det == 0; not invertible.")
#     330 if use_exact:
#     331     dMi = dMi.convert_to(dom)
#
# NonInvertibleMatrixError: Matrix det == 0; not invertible.
