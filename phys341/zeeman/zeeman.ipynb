# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## $B$ vs. Current

# %%
I = np.array(
    [
        0.020,
        0.231,
        0.443,
        0.656,
        0.868,
        1.082,
        1.294,
        1.508,
        1.721,
        1.933,
        2.144,
        2.356,
        2.567,
        2.776,
        2.987,
        3.079,
    ]
)  # A, unc = 0.001 A

B = np.array(
    [
        56.00,
        184.0,
        333.0,
        420.0,
        490.0,
        780.0,
        830.0,
        980.0,
        1170,
        1380,
        1470,
        1600,
        1710,
        1760,
        1860,
        2100,
    ]
)  # G, unc = 20 G

# %% [markdown]
# ## Split Peaks

# %%
ISplits = np.array(
    [
        3.079,
        2.983,
        2.823,
        2.693,
        2.491,
        2.290,
        2.049,
    ]
)
ARight = np.array(
    [
        0.962,
        1.005,
        1.005,
        0.984,
        1.005,
        1.005,
        1.005,
    ]
)
AplusRight = np.array(
    [
        1.027,
        1.048,
        1.048,
        1.027,
        1.027,
        1.027,
        1.027,
    ]
)
AminusRight = np.array(
    [
        0.920,
        0.962,
        0.962,
        0.941,
        0.962,
        0.962,
        0.962,
    ]
)

# %%
splitdf = pd.DataFrame()
splitdf["current"] = ISplits
splitdf[""]

# %%
ALeft = np.array([-0.727, -0.727, -0.727, -0.706, -0.706, -0.706, -0.727])
AplusLeft = np.array([-0.770, -0.770, -0.770, -0.749, -0.749, -0.749, -0.749])
AminusLeft = np.array([-0.684, -0.684, -0.684, -0.663, -0.663, -0.684, -0.684])

IFSR = np.array([5.022, 4.782, 4.617, 4.235, 3.799, 3.401, 3.079, 2.596, 2.195])

ALower = np.array([0.920, 1.069, 1.069, 1.069, 1.069, 1.048, 1.048, 1.048, 1.027])
AHigher = np.array([1.091, 1.326, 1.326, 1.326, 1.326, 1.347, 1.347, 1.347, 1.347])
