# %% [markdown]
# ## Experimental g-Factor Values

# %%
import pandas as pd
import sys
from pathlib import Path
import scipy.constants as const
import math

sys.path.insert(0, str(Path.cwd().parent))

# %%
freq_unc = 0.01
b1_unc = 0.001
b2_unc = 0.001
pd.read_csv("g_factor.csv")
# Out:
#      freq  b87_volt  b85_volt
# 0   75.53    0.3500    0.4384
# 1  100.69    0.4050    0.5218
# 2  125.04    0.4603    0.6051
# 3  150.15    0.5181    0.6924
# 4  174.96    0.5764    0.7789
# 5  200.13    0.6347    0.8663

# %%
MU0 = 4 * math.pi * 1e-7  # vacuum permeability, T·m/A


def helmholtz_field(I, N, R, mu0=MU0):
    if R <= 0:
        raise ValueError("R must be positive (meters).")
    return ((4 / 5) ** 1.5) * (mu0 * N * I / R)

# %%
const.mu_0
# Out:
# 1.25663706127e-06

# %%
def current_to_field(I):
    N = 
    return (4 /5)**(3/2) * const.mu_0 *
