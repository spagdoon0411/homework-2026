# %%
import numpy as np

# %%
speeds = np.array(
    [
        14.4,
        15.4,
        27.2,
        43.6,
        25.1,
        18.4,
        34.4,
        22.3,
        37.8,
        33.0,
        47.8,
        25.1,
        9.1,
        24.9,
        44.8,
        17.0,
        28.7,
        34.5,
        40.5,
        26.1,
    ]
)

# %%
speeds
# Out:
# array([14.4, 15.4, 27.2, 43.6, 25.1, 18.4, 34.4, 22.3, 37.8, 33. , 47.8,
#        25.1,  9.1, 24.9, 44.8, 17. , 28.7, 34.5, 40.5, 26.1])

# %%
speeds.mean()
# Out:
# np.float64(28.505000000000003)

# %%
speeds.std(ddof=1)
# Out:
# np.float64(10.884052795864134)

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df["speed"] = speeds

# %%
df
# Out:
#     speed
# 0    14.4
# 1    15.4
# 2    27.2
# 3    43.6
# 4    25.1
# 5    18.4
# 6    34.4
# 7    22.3
# 8    37.8
# 9    33.0
# 10   47.8
# 11   25.1
# 12    9.1
# 13   24.9
# 14   44.8
# 15   17.0
# 16   28.7
# 17   34.5
# 18   40.5
# 19   26.1

# %%
df.hist(bins=range(5, 70, 10), width=2)
# Out:
# array([[<Axes: title={'center': 'speed'}>]], dtype=object)
