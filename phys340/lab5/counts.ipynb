# %%
import numpy as np
import pandas as pd

background = 528  # for 100s

low = np.array(
    [
        0,
    ]
)

high = np.array(
    [
        6040,
        5761,
        5658,
        5867,
        5657,
        5957,
        5631,
        5634,
        5551,
        5339,
        5488,
        5566,
        5670,
        5503,
        5419,
        5649,
        5547,
        5308,
        5598,
        5524,
        5313,
        5730,
        5529,
        5338,
        5426,
        5592,
        5327,
        5546,
        5253,
        5168,
        5363,
        5270,
        5146,
        5369,
        5209,
        5332,
        4835,
        5320,
        5106,
        4905,
        4852,
        4617,
        5130,
        5230,
        4750,
        4664,
        4539,
        4892,
        4928,
        4673,
        4815,
        4970,
        4615,
        4662,
        4965,
        4445,
        4392,
        4262,
        4298,
        4197,
        4160,
        4205,
    ]
)

print(len(low))
print(len(high))
# Out:
# 1
# 62

# %%
df = pd.DataFrame()
df["readings"] = high

# %%
df["index"] = np.arange(len(high))

# %%
df.plot.scatter(x="index", y="readings")
# Out:
# <Axes: xlabel='index', ylabel='readings'>

# %%
df["readings"].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>
